# %% [markdown]
# ## This is the langchain Version v1

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_AI_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent


agent = create_agent(
    model="gpt-5",
    tools=[],
    system_prompt="You are helpful assistant"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.agents import create_agent
#       4 agent = create_agent(
#       5     model="gpt-5",
#       6     tools=[],
#       7     system_prompt="You are helpful assistant"
#       8 )
#
# File c:\LLM\Langchain\venv\lib\site-packages\langchain\agents\__init__.py:56
#      54 from langchain.agents.conversational.base import ConversationalAgent
#      55 from langchain.agents.conversational_chat.base import ConversationalChatAgent
# ---> 56 from langchain.agents.initialize import initialize_agent
#      57 from langchain.agents.json_chat.base import create_json_chat_agent
#      58 from langchain.agents.loading import load_agent
#
# File c:\LLM\Langchain\venv\lib\site-packages\langchain\agents\initialize.py:14
#      12 from langchain.agents.agent import AgentExecutor
# ...
